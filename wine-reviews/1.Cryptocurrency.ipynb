# %%
# Import Dependencies
import pandas as pd

# %%
df1 = pd.read_csv("winemag-data_first150k.csv")
df2 = pd.read_csv("winemag-data-130k-v2.csv")
df2.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
df1 = df1.set_index("Un")

# %%
df = pd.merge(df1, df2, on="Unnamed: 0")
df.tail()
# Out:
#         Unnamed: 0 country_x  \
# 129966      129966   Austria
# 129967      129967        US
# 129968      129968        US
# 129969      129969    France
# 129970      129970   Austria
#
#                                             description_x   designation_x  \
# 129966  A finely structured wine, packed with ripe fru...       Solitaire
# 129967  Rich and appealing, a new bottling from the wi...  Emelia's Cuvée
# 129968  From warm, dry vineyards in the eastern Vaca m...             NaN
# 129969  A beautifully crisp wine, fresh and leaping wi...             NaN
# 129970  Vulcano is the German spelling. Quite a mix of...         Vulcano
#
#         points_x  price_x        province_x            region_1_x region_2_x  \
# 129966        90     50.0        Burgenland                   NaN        NaN
# 129967        90     36.0        California  Russian River Valley     Sonoma
# 129968        90     24.0        California           Napa Valley       Napa
# ...

# %%
df.dropna()
# Out:
#         Unnamed: 0 country_x  \
# 23              23        US
# 67              67        US
# 75              75        US
# 144            144        US
# 146            146        US
# 169            169        US
# 198            198        US
# 199            199        US
# 233            233        US
# 248            248        US
# 262            262        US
# 301            301        US
# 341            341        US
# 362            362        US
# 388            388        US
# 409            409        US
# 421            421        US
# 429            429        US
# 431            431        US
# 480            480        US
# 501            501        US
# 510            510        US
# 513            513        US
# 516            516        US
# 520            520        US
# 522            522        US
# 523            523        US
# 524            524        US
# 531            531        US
# 538            538        US
# ...            ...       ...
# ...

# %%
# Merge the two DataFrames together based on the Dates they share
merge_table = pd.merge(bitcoin_df, dash_df, on="Date")
merge_table.head()
# Out:
#         Date  Open_x  High_x   Low_x  Close_x     Volume_x   Market Cap_x  \
# 0  17-Sep-17  438.90  438.90  384.06   419.86  221828000.0  7,279,520,000
# 1  16-Sep-17  424.49  450.98  388.20   440.22  313583000.0  7,039,590,000
# 2  15-Sep-17  369.49  448.39  301.69   424.02  707231000.0  6,126,800,000
# 3  14-Sep-17  504.22  510.47  367.04   367.04  257431000.0  8,359,650,000
# 4  13-Sep-17  509.47  519.20  471.22   503.61  340344000.0  8,445,540,000
#
#    Open_y  High_y   Low_y  Close_y    Volume_y   Market Cap_y
# 0  298.59  315.58  278.17   313.84  38081600.0  2,257,850,000
# 1  284.50  301.23  276.57   298.86  43702600.0  2,150,800,000
# 2  236.05  300.11  220.51   284.36  72695500.0  1,784,040,000
# 3  301.11  303.74  236.24   236.24  35013800.0  2,275,100,000
# 4  324.72  325.16  287.25   301.29  28322500.0  2,452,930,000

# %%
# Rename columns so that they are differentiated
merge_table.rename(columns={"Open_x":"Open Bitcoin","High_x":"High Bitcoin"})
merge_table.head()
# Out:
#         Date  Open_x  High_x   Low_x  Close_x     Volume_x   Market Cap_x  \
# 0  17-Sep-17  438.90  438.90  384.06   419.86  221828000.0  7,279,520,000
# 1  16-Sep-17  424.49  450.98  388.20   440.22  313583000.0  7,039,590,000
# 2  15-Sep-17  369.49  448.39  301.69   424.02  707231000.0  6,126,800,000
# 3  14-Sep-17  504.22  510.47  367.04   367.04  257431000.0  8,359,650,000
# 4  13-Sep-17  509.47  519.20  471.22   503.61  340344000.0  8,445,540,000
#
#    Open_y  High_y   Low_y  Close_y    Volume_y   Market Cap_y
# 0  298.59  315.58  278.17   313.84  38081600.0  2,257,850,000
# 1  284.50  301.23  276.57   298.86  43702600.0  2,150,800,000
# 2  236.05  300.11  220.51   284.36  72695500.0  1,784,040,000
# 3  301.11  303.74  236.24   236.24  35013800.0  2,275,100,000
# 4  324.72  325.16  287.25   301.29  28322500.0  2,452,930,000

# %%
# alternatively you can set your suffixes when the merge occurs

# %%
# Collecting best open for Bitcoin and Dash


# Collecting best close for Bitcoin and Dash


# Collecting the total volume for Bitcoin and Dash

# %%
# Creating a summary DataFrame using above values
